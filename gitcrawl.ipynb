# %%
from selenium import webdriver

# %%
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
# User information obtained from github using selenium is saved in info_dic
info_dic = {}
driver=webdriver.Chrome(executable_path = "/Users/zhemei/Desktop/chromedriver")
driver.get("https://github.com/xli2257")
h1 = driver.find_element_by_xpath('//*[@id="js-pjax-container"]/div[2]/div/div[1]/div/div[2]/div[1]/div[1]/a/img').click();
info = driver.current_url
info_dic['User_ID'] = info.split('/')[-1][0:-4]
info_dic['Avatar_url'] = info
driver.back()
h1 = driver.find_element_by_xpath('//*[@id="js-pjax-container"]/div[1]/div/div/div[2]/div/nav/a[3]').click();
info = driver.current_url
info_dic['Project_url'] = info
driver.back()
h1 = driver.find_element_by_xpath('//*[@id="js-pjax-container"]/div[1]/div/div/div[2]/div/nav/a[2]').click();
info = driver.current_url
info_dic['Repo_url'] = info
driver.quit()

# %%
info_dic
# Out:
# {'User_ID': '89955569',
#  'Avatar_url': 'https://avatars.githubusercontent.com/u/89955569?v=4',
#  'Project_url': 'https://github.com/xli2257?tab=projects',
#  'Repo_url': 'https://github.com/xli2257?tab=repositories'}

# %%
#This is probably wrong but it reads the webpage generated by REST API
driver=webdriver.Chrome(executable_path = "/Users/zhemei/Desktop/chromedriver")
driver.get("https://api.github.com/users/xli2257")
